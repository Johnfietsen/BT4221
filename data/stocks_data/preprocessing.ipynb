# %% [markdown]
# # Stock Market Data

# %%
import pandas as pd
from datetime import datetime, timedelta, date
import csv

# %% [markdown]
# ## Loadind the data

# %%
citi = pd.read_csv("C-intra.csv")
goldman = pd.read_csv("GS-intra.csv")
morgan = pd.read_csv("MS-intra.csv")

# %% [markdown]
# ---

# %% [markdown]
# ## Overview of the dataframe

# %%
citi.head()
# Out:
#      <DATE>  <TIME>  <OPEN>  <HIGH>  <LOW>  <CLOSE>   <VOL>
# 0  20191008  100000  67.050   67.05  66.34    66.34  113224
# 1  20191008  110000  66.320   66.50  66.03    66.50  163117
# 2  20191008  120000  66.495   66.84  66.19    66.65  105768
# 3  20191008  130000  66.650   67.17  66.60    66.91   91339
# 4  20191008  140000  66.920   67.03  66.87    66.87  100957

# %%
goldman.head()
# Out:
#      <DATE>  <TIME>  <OPEN>  <HIGH>   <LOW>  <CLOSE>  <VOL>
# 0  20191008  100000  197.59  197.71  196.28   196.30  22894
# 1  20191008  110000  196.30  197.50  195.94   197.50  28411
# 2  20191008  120000  197.46  198.30  196.61   197.39  25527
# 3  20191008  130000  197.41  198.78  197.21   197.98  20972
# 4  20191008  140000  198.01  198.56  197.86   198.05  10451

# %%
morgan.head()
# Out:
#      <DATE>  <TIME>  <OPEN>  <HIGH>  <LOW>  <CLOSE>  <VOL>
# 0  20191008  110000   39.93  40.025  39.78    40.01  33348
# 1  20191008  120000   40.00  40.150  39.75    40.00  34901
# 2  20191008  130000   39.96  40.150  39.92    40.02  21383
# 3  20191008  140000   39.99  40.190  39.99    40.08  13972
# 4  20191008  150000   40.10  40.150  39.94    39.98  29330

# %% [markdown]
# ---

# %% [markdown]
# ## Standardization of data

# %%
files = [citi , goldman, morgan]

# %% [markdown]
# #### Remove '<' and '>' from columns names

# %%
def columns_names(files):
    for data in files:
        data.columns = data.columns.str.replace('<', '').str.replace('>', '')

# %%
columns_names(files)

# %%
citi.head()
# Out:
#        DATE    TIME    OPEN   HIGH    LOW  CLOSE     VOL
# 0  20191008  100000  67.050  67.05  66.34  66.34  113224
# 1  20191008  110000  66.320  66.50  66.03  66.50  163117
# 2  20191008  120000  66.495  66.84  66.19  66.65  105768
# 3  20191008  130000  66.650  67.17  66.60  66.91   91339
# 4  20191008  140000  66.920  67.03  66.87  66.87  100957

# %% [markdown]
# #### Standadize date and time

# %%
def to_date(files):
    for data in files:
        data['DATE'] = data['DATE'].map(str) + data['TIME'].map(str)
        data["DATE"]= pd.to_datetime(data["DATE"],format="%Y%m%d%H%M%S") 

        data.drop(['TIME'],axis=1,inplace=True)

# %%
to_date(files)

# %%
citi.head()
# Out:
#                  DATE    OPEN   HIGH    LOW  CLOSE     VOL
# 0 2019-10-08 10:00:00  67.050  67.05  66.34  66.34  113224
# 1 2019-10-08 11:00:00  66.320  66.50  66.03  66.50  163117
# 2 2019-10-08 12:00:00  66.495  66.84  66.19  66.65  105768
# 3 2019-10-08 13:00:00  66.650  67.17  66.60  66.91   91339
# 4 2019-10-08 14:00:00  66.920  67.03  66.87  66.87  100957

# %%
citi["DATE"] = citi["DATE"] + timedelta(days=1)
goldman["DATE"] = goldman["DATE"] + timedelta(days=1)
morgan["DATE"] = morgan["DATE"] + timedelta(days=1)

# %% [markdown]
# ---

# %% [markdown]
# ## Add stock change for future correlation

# %% [markdown]
# The percentage change in stock market is calculated from the price the market had closed the hour before. In the case of the start of the day, we take the closing price from the previous day.

# %%
def add_change(files):
    for data in files:
        list_change = []
        for index, row in data.iterrows():
            if index == 0:
                list_change.append(0)
            else:
                res = ((row['CLOSE']) - (data['CLOSE'][index-1])) / (data['CLOSE'][index-1])
                list_change.append(res*100)
        data['%CHANGE'] = list_change

# %%
add_change(files)

# %%
citi.head()
# Out:
#                  DATE    OPEN   HIGH    LOW  CLOSE     VOL   %CHANGE
# 0 2019-10-09 10:00:00  67.050  67.05  66.34  66.34  113224  0.000000
# 1 2019-10-09 11:00:00  66.320  66.50  66.03  66.50  163117  0.241182
# 2 2019-10-09 12:00:00  66.495  66.84  66.19  66.65  105768  0.225564
# 3 2019-10-09 13:00:00  66.650  67.17  66.60  66.91   91339  0.390098
# 4 2019-10-09 14:00:00  66.920  67.03  66.87  66.87  100957 -0.059782

# %% [markdown]
# ---

# %% [markdown]
# ####  %Change 1h after every day opening

# %%
def add_change2(files):
    for data in files:
        if (data.equals(morgan)):
            list_change = []
            for index, row in data.iterrows():
                if ((row['DATE'].to_pydatetime().hour == 12) & (index != 1)):
                    res = ((row['CLOSE']) - (data['CLOSE'][index - 2])) / (data['CLOSE'][index - 2])
                    list_change.append(res*100)
                else:
                    list_change.append(0)
                
        else:   
            list_change = []
            for index, row in data.iterrows():
                if ((row['DATE'].to_pydatetime().hour == 11) & (index != 1)):
                    res = ((row['CLOSE']) - (data['CLOSE'][index - 2])) / (data['CLOSE'][index - 2])
                    list_change.append(res*100)
                else:
                    list_change.append(0)
                
        data['%CHANGE_1H'] = list_change

# %%
add_change2(files)

# %%
citi.loc[:10]
# Out:
#                   DATE    OPEN   HIGH    LOW   CLOSE     VOL   %CHANGE  \
# 0  2019-10-09 10:00:00  67.050  67.05  66.34  66.340  113224  0.000000
# 1  2019-10-09 11:00:00  66.320  66.50  66.03  66.500  163117  0.241182
# 2  2019-10-09 12:00:00  66.495  66.84  66.19  66.650  105768  0.225564
# 3  2019-10-09 13:00:00  66.650  67.17  66.60  66.910   91339  0.390098
# 4  2019-10-09 14:00:00  66.920  67.03  66.87  66.870  100957 -0.059782
# 5  2019-10-09 15:00:00  66.890  67.11  66.63  66.775  103199 -0.142067
# 6  2019-10-09 16:00:00  66.790  66.97  66.32  66.425  166816 -0.524148
# 7  2019-10-10 10:00:00  66.900  67.18  66.79  67.035   50634  0.918329
# 8  2019-10-10 11:00:00  67.030  67.36  66.85  67.120   86032  0.126799
# 9  2019-10-10 12:00:00  67.160  67.49  66.97  67.290   53317  0.253278
# 10 2019-10-10 13:00:00  67.310  67.42  67.26  67.375   45015  0.126319
#
#     %CHANGE_1H
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3     0.000000
# 4     0.000000
# 5     0.000000
# 6     0.000000
# 7     0.000000
# 8
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3     0.000000
# 4     0.000000
# 5     0.000000
# 6     0.000000
# 7     0.000000
# 8     0.329097
# 9     0.000000
# 10    0.000000
# 11    0.000000
# 12    0.000000
# 13    0.000000
# 14    0.000000
# 15    2.017584
# 16    0.000000
# 17    0.000000
# 18    0.000000
# 19    0.000000
# 20    0.000000
# 21    0.000000
# 22    3.198038
# 23    0.000000
# 24    0.000000
# 25    0.000000
# 26    0.000000
# 27    0.000000
# 28    0.000000
# 29   -0.278511
# ..         ...
# 61    0.000000
# 62    0.000000
# 63    0.000000
# 64    1.562500
# 65    0.000000
# 66    0.000000
# 67    0.000000
# 68    0.000000
# 69    0.000000
# 70    0.000000
# 71    0.563973
# 72    0.000000
# 73    0.000000
# 74    0.000000
# 75    0.000000
# 76    0.000000
# 77    0.000000
# 78    0.787514
# 79    0.000000
# 80    0.000000
# 81    0.000000
# 82    0.000000
# 83    0.000000
# 84    0.000000
# 85   -0.194000
# 86    0.000000
# 87    0.000000
# 88    0.000000
# 89    0.000000
# 90    0.000000
#
# [91 rows x 8 columns]

# %%
# little hacky code to get changes of a day on one row and make the file titles same as the tweet files

temp = {}

for company in ["Citigroup_", "goldmansachs_", "morganstanley_"]:
    if company == "Citigroup_":
        comp = citi
    elif company == "goldmansachs_":
        comp = goldman
    else:
        comp = morgan
    day_old = ""
    i = 0
    for index, row in comp.iterrows():
        date = str(row["DATE"]).split(" ")
        day = date[0]
        time = date[1]

        # new day, make new key
        if day != day_old:
            day_old = day
            temp[company + day] = [row["%CHANGE"]]
        else:
            temp[company + day].append(row["%CHANGE"])
        i += 1
      
print(temp)
# Out:
# {'Citigroup_2019-10-09': [0.0, 0.24118179077479135, 0.22556390977444465, 0.3900975243810816, -0.05978179644297123, -0.14206669657544319, -0.5241482590790093], 'Citigroup_2019-10-10': [0.9183289424162581, 0.12679943313195788, 0.2532777115613851, 0.12631891811560964, 0.007421150278286386, 0.2077767883645007, -0.1481042654028352], 'Citigroup_2019-10-11': [2.4918421833283784, 0.17366136034732932, -0.05778676683038434, -0.4047412546978912, -0.26124818577649755, -0.11641443538998589, 0.029137529137523342], 'Citigroup_2019-10-12': [2.8109525196621132, -0.09916418756198808, 0.02127056154282554, -0.19848302261288803, 0.277008310249318, 0.07083156254426569, -0.8069082672706787], 'Citigroup_2019-10-15': [-0.2854288568574121, 0.08587376556462326, 0.6721006721006704, 0.07102272727272323, 0.01419446415896509, -0.25546409310245904, -0.08537279453614438], 'Citigroup_2019-10-16': [-0.17089148390772507, 2.482168330955791, -0.30623608017817217, 0.27925160569671686, -0.3480924533556113, 0.11177867821714757, -0.5582693649686052], 'Citigroup_2019-10-17': [-1.291228070175441, 0.07109341674960494, -0.5683432793407097, -0.41440411546156936, 0.014349261013065167, 0.4017216642754679, -0.7002000571592013], 'Citigroup_2019-10-18': [1.036120305079866, -0.8403361344537662, -0.38781959207125855, 0.29560201874551195, 0.30910790022282963, 0.35832019492618605, -0.6141102542130714], 'Citigroup_2019-10-19': [0.3736168989797254, -0.31496062992125823, -0